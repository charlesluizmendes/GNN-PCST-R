# %% [markdown]
# ## Imports

# %%
import os
import shutil

# %% [markdown]
# ## Limpar

# %% [markdown]
# Limpar o diretório "outputs" para iniciar uma nova execução.

# %%
root_dir = os.getcwd()
output_dir = "outputs"

# %%
shutil.rmtree(os.path.join(root_dir, output_dir), ignore_errors=True)

# %% [markdown]
# ### Dataset

# %% [markdown]
# Executando os notebooks para a criação do Dataset AS

# %%
os.chdir('src/dataset')

# %%
# %run buildSnapshots.ipynb
# Out:
# Mapeando nós: 100%|██████████| 120/120 [01:25<00:00,  1.40it/s]
# build_snapshots: construindo grafo: 100%|██████████| 922674/922674 [00:06<00:00, 135189.15aresta/s]
#   -> Servidor: node_id=131, grau=4889
# build_snapshots: classificando antenas: 100%|██████████| 101606/101606 [00:00<00:00, 6329424.07nó/s]
#   -> Antenas identificadas: 18178 nós
# Gerando grafos: 100%|██████████| 120/120 [02:01<00:00,  1.01s/it]
