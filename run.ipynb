# %% [markdown]
# ## Imports

# %%
import os
import shutil

# %% [markdown]
# ## Execução

# %% [markdown]
# ### Limpar

# %% [markdown]
# Limpar o diretório "outputs" para iniciar uma nova execução.

# %%
root_dir = os.getcwd()
output_dir = "outputs"

# %%
shutil.rmtree(os.path.join(root_dir, output_dir), ignore_errors=True)

# %% [markdown]
# ### Dataset

# %% [markdown]
# Executando os notebooks para a criação do Dataset AS

# %%
os.chdir(os.path.join(root_dir, 'src', 'dataset'))

# %%
# %run buildSnapshots.ipynb
# Out:
# Mapeando nós: 100%|██████████| 120/120 [01:19<00:00,  1.51it/s]
# build_snapshots: construindo grafo: 100%|██████████| 922674/922674 [00:06<00:00, 137391.77aresta/s]
#   -> Servidor: node_id=131, grau=4889
# build_snapshots: classificando antenas: 100%|██████████| 101606/101606 [00:00<00:00, 6508941.75nó/s]
#   -> Antenas identificadas: 18178 nós
# Gerando grafos: 100%|██████████| 120/120 [02:04<00:00,  1.04s/it]

# %% [markdown]
# ### Retornar

# %% [markdown]
# Retornar ao diretório raiz

# %%
os.chdir(root_dir)
