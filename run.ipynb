# %% [markdown]
# ## Imports

# %%
import os
import shutil

# %% [markdown]
# ## Execução

# %% [markdown]
# ### Limpar

# %% [markdown]
# Limpar o diretório "outputs" para iniciar uma nova execução.

# %%
root_dir = os.getcwd()
output_dir = "outputs"

# %%
shutil.rmtree(os.path.join(root_dir, output_dir), ignore_errors=True)

# %% [markdown]
# ### Dataset

# %% [markdown]
# Executando os notebooks para a criação do Dataset AS

# %%
os.chdir(os.path.join(root_dir, 'src', 'dataset'))

# %%
# %run 1.snapshots.ipynb
# Out:
# snapshots: mapeando snapshots: 100%|██████████| 120/120 [01:06<00:00,  1.81snapshot/s]
#   -> spapshots identificadas: 120 snapshots
# snapshots: construindo grafo: 100%|██████████| 922674/922674 [00:03<00:00, 276804.48aresta/s]
#   -> servidor: node_id=131, grau=4889
# snapshots: classificando antenas: 100%|██████████| 101606/101606 [00:00<00:00, 4632747.61nó/s]
#   -> antenas identificadas: 18178 nós
# snapshots: gerando grafos .pt: 100%|██████████| 120/120 [01:35<00:00,  1.26grafo/s]

# %%
# %run 2.instances.ipynb
# Out:
# instances: escrevendo instances.jsonl: 100%|██████████| 595/595 [08:21<00:00,  1.19instância/s]
#   -> instances geradas: 595

# %% [markdown]
# ### Retornar

# %% [markdown]
# Retornar ao diretório raiz

# %%
os.chdir(root_dir)
